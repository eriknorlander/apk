# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/produkter.csv', sep=';')

# %%
df['Alkoholhalt'] = df['Alkoholhalt'].apply(lambda x: float(x[:-1])/100)

# %%
df['AlkoholVol'] = df['Alkoholhalt']*df['Volymiml']

# %%
df['apk'] = df['AlkoholVol']/df['Prisinklmoms']

# %%
df.apk.hist(bins=100)

# %%
df.loc[df.apk != 0].sort_values('apk', ascending=False).head(20)
# Out:
#             nr  Artikelid  Varnummer                 Namn  \
# 17789   228401     942581       2284          Ferrandière
# 13080   129612     507799       1296   Pripps Extra Stark
# 13127   156812     508323       1568      Sju komma tvåan
# 16023  7638508     800520      76385          Little Hero
# 13105   127312     508019       1273     Sofiero Original
# 4558   7432702   15355746      74327  The Long Little Dog
# 13114  1122812     508176      11228         Three Hearts
# 13136  1139212     508393      11392          Arboga 10,2
# 13125   144612     508314       1446                 Kung
# 8143   1279708      22289      12797   Castillo de Gredos
# 12734  7350308     441400      73503               Torero
# 2207    260208    1152052       2602               Menada
# 14084  7525308     617348      75253           Pata Negra
# 13078  1139312     507789      11393           Millennium
# 13460  8811801     543706      88118   Falcon Strong Brew
# ...
